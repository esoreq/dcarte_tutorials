# %% [markdown]
# ## Derived datasets
#
# We've already gone through how to use DCARTE to get UKDRI CRT raw datasets. However, a central element in the process of knowledge discovery (aka data science) is the creation of features that fuse different data sources, transform a single data source using some logic, or aggregate datasets to a relevant frequency.
#
# Let's create a step by step example that will make this point simpler to follow.

# %% [markdown]
# We start by importing dcarte and loading PIR Activity across the houses

# %%
import dcarte 
import pandas as pd 
import seaborn as sns 
activity = dcarte.load('Activity','raw')
activity.start_date.agg(['min','max','count'])
# Out:
# Finished Loading Activity in:                  3.0 seconds
# min      2020-12-09 14:53:17
# max      2022-03-15 13:22:12
# count                6294321
# Name: start_date, dtype: object

# %% [markdown]
# We then inspect the DataFrame's info()

# %%
activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6294321 entries, 0 to 6294320
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   start_date     datetime64[ns]
#  1   patient_id     object
#  2   home_id        object
#  3   location_id    object
#  4   location_name  object
#  5   source         object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 288.1+ MB

# %% [markdown]
# In this example, we wish to convert the raw activity data into a wide one-hot encoding tabular format that allows us to easily analyse the level of activity among households over time (e.g. every six hours every day or every week). One of the first things we should look at is the frequency of activity throughout the various locations in order to simplify the data by deleting or merging certain areas around the household. The best technique to find such targets is to use the pandas plotting capabilities.

# %%
activity.location_name.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The first step is to eliminate unique locations only in a few houses and combine contextually similar locations. This will make it easier to generalise our findings across all homes.

# %%
location_by_pid =  pd.crosstab(activity.location_name,activity.patient_id)
location_by_pid
# Out:
# patient_id     2GN1PHeHwRzNYQ7q4Nvg7g  2TmRrtnsd3WisLYTmw5id1  \
# location_name
# WC1                                 0                       0
# bathroom1                        3509                     126
# bedroom1                        20576                     408
# cellar                              0                       0
# conservatory                        0                       0
# corridor1                           0                       0
# dining room                         0                       0
# hallway                          9561                     568
# kitchen                         18917                     384
# living room                         0                       0
# lounge                          13572                     286
# office                              0                       0
# study                               0                       0
#
# patient_id     2zbyXzYNKPwiPtjaA2L64o  3LXU9Vf5dVsXtnJwxAhaN6  \
# location_name
# WC1                                 0                       0
# bathroom1                       19547                   15532
# bedroom1                        21122                    3418
# cellar                              0                       0
# conservatory                        0                       0
# corridor1                           0                       0
# dining room                         0                       0
# hallway                         41467                    2735
# kitchen                         59558                       0
# living room                         0                       0
# lounge                          28120                     641
# office                              0                       0
# study                           10828                       0
#
# patient_id     3hY7Mp7u9YPo1xMARSxLhc  4h1dAuzg9rdrhyojwxUS26  \
# location_name
# WC1                                 0                       0
# bathroom1                       16848                   30386
# bedroom1                        19612                   30672
# cellar                              0                       0
# conservatory                        0                       0
# corridor1                           0                       0
# dining room                     61311                       0
# hallway                             0                   21455
# kitchen                         44737                   47643
# living room                         0                       0
# lounge                          26965                   49330
# office                              0                       0
# study                               0                       0
#
# patient_id     576646jHRwm4KkF9uzRnaC  5aQpCSrtPFyympF2G14a6c  \
# location_name
# WC1                                 0                       0
# bathroom1                        2632                     529
# bedroom1                         6476                     477
# cellar                              0                       0
# conservatory                        0                       0
# corridor1                           0                       0
# dining room                         0                       0
# hallway                             0                    5366
# kitchen                         13244                    5222
# living room                         0                       0
# lounge                           1282                    5452
# office                              0                       0
# study                               0                       0
#
# patient_id     5xSoeEijWNFxswzMEAih71  64RLyRh1fEUutdhMnvu17d  ...  \
# location_name                                                  ...
# WC1                                 0                       0  ...
# bathroom1                         160                   10806  ...
# bedroom1                          884                   12204  ...
# cellar                              0                       0  ...
# conservatory                        0                       0  ...
# corridor1                           0                       0  ...
# dining room                         0                       0  ...
# hallway                          2860                   13721  ...
# kitchen                          4256                   25494  ...
# living room                         0                       0  ...
# lounge                           1408                   16829  ...
# office                              0                       0  ...
# study                               0                       0  ...
#
# patient_id     WgTjg4VRZSr4r7bCSdSetZ  WrXiKEAY93k5DhEinCTC6y  \
# location_name
# WC1                                 0                       0
# bathroom1                         698                    1171
# bedroom1                          687                    3011
# cellar                              0                       0
# conservatory                        0                       0
# corridor1                           0                       0
# dining room                         0                       0
# hallway                          2708                    1733
# kitchen                          2808                    2940
# living room                         0                       0
# lounge                           1222                    3899
# office                              0                       0
# study                               0                       0
#
# patient_id     WtYLx1dEr6hHgQDg8TKcGP  X7dJAZjrhEa1kRFUkoZVvg  \
# location_name
# WC1                                 0                       0
# bathroom1                        9356                    3897
# bedroom1                        40621                    3740
# cellar                              0                       0
# conservatory                        0                       0
# corridor1                           0                       0
# dining room                      5937                       0
# hallway                         44856                   14632
# kitchen                         56556                   10373
# living room                         0                       0
# lounge                          49265                   10091
# office                              0                       0
# study                               0                       0
#
# patient_id     XsfBVz6GP7XtvhY4CiAvuf  Xv41AaXiVYBKFAa7SLq8F5  \
# location_name
# WC1                                 0                       0
# bathroom1                        5028                    2901
# bedroom1                        21952                    7696
# cellar                              0                       0
# conservatory                        0                       0
# corridor1                           0                       0
# dining room                         0                       0
# hallway                         13702                    6442
# kitchen                         49428                    8332
# living room                         0                   15061
# lounge                          30690                       0
# office                              0                       0
# study                               0                       0
#
# patient_id     XvG4pZADpDNdWsQfKrAt9a  YJMET4inKfFcBERma2tQRi  \
# location_name
# WC1                                 0                       0
# bathroom1                           0                    1396
# bedroom1                         8376                    2969
# cellar                              0                       0
# conservatory                        0                       0
# corridor1                       15764                       0
# dining room                         0                       0
# hallway                          7724                    4810
# kitchen                         13582                    5442
# living room                      4187                       0
# lounge                           1905                    3099
# office                              0                       0
# study                               0                       0
#
# patient_id     YQb22UBcPbedJqEiKAqvDU  YYGGmsEaf2gP4JNN9kMprV
# location_name
# WC1                                 0                       0
# bathroom1                           9                   15302
# bedroom1                           12                    9161
# cellar                              0                       0
# conservatory                        0                       0
# corridor1                           0                       0
# dining room                         0                       0
# hallway                           873                    4242
# kitchen                          3333                   25864
# living room                         0                       0
# lounge                           4343                   14805
# office                              0                       0
# study                               0                       0
#
# [13 rows x 89 columns]

# %%
ax = sns.heatmap(location_by_pid>0,cbar=False)
ax.tick_params(left=False, bottom=False)
ax.set_xticklabels([]);

# %% [markdown]
# A simple interpretation of the above plot can be to do the following cleaning tasks:
# - filter the cellar and the conservatory,
# - merge WC1 and bathroom1
# - merge study and office
# - merge the lounge, dining room and living room
# - merge the corridor and hallway
#
# Let's see an example of how to do this using pandas

# %%
mask = ~activity.location_name.isin(['cellar','conservatory'])
activity = activity[mask]
activity.location_name.unique()
# Out:
# array(['bedroom1', 'kitchen', 'bathroom1', 'lounge', 'hallway',
#        'dining room', 'living room', 'corridor1', 'WC1', 'study',
#        'office'], dtype=object)

# %% [markdown]
# There are many ways to remap one value into another value in Python. However, in the process of transparency, interpretability and ease of change, I find the dictionary approach shown below to be the simplest to foolow and implement.

# %%
mapping = {
    'bedroom1':'bedroom', 
    'bathroom1':'bathroom', 
    'hallway':'hallway', 
    'lounge':'lounge', 
    'kitchen':'kitchen',
    'living room':'lounge', 
    'corridor1':'hallway', 
    'dining room':'lounge', 
    'WC1':'bathroom', 
    'study':'study',
    'office':'study'}
activity.location_name = activity.location_name.map(mapping)
activity.location_name.unique()
# Out:
# array(['bedroom', 'kitchen', 'bathroom', 'lounge', 'hallway', 'study'],
#       dtype=object)

# %% [markdown]
# Revisiting the plots we used before is a useful sanity check to validate that the changes we made we applied.

# %%
activity.location_name.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
ax = sns.heatmap(pd.crosstab(activity.location_name,activity.patient_id)>0,cbar=False)
ax.tick_params(left=False, bottom=False)
ax.set_xticklabels([]);

# %% [markdown]
# After cleaning the location_name we can select just columns of intrest by passing a list of columns names to the DataFrame.

# %%
activity[['start_date','patient_id','location_name']]
# Out:
#                  start_date              patient_id location_name
# 0       2020-12-09 14:53:17  Dr1tnvKDk2bHG8YS21nwiR       bedroom
# 1       2020-12-09 14:53:18  Dr1tnvKDk2bHG8YS21nwiR       kitchen
# 2       2020-12-09 14:53:18  Dr1tnvKDk2bHG8YS21nwiR      bathroom
# 3       2020-12-09 14:53:19  Dr1tnvKDk2bHG8YS21nwiR        lounge
# 4       2020-12-09 14:53:36  Dr1tnvKDk2bHG8YS21nwiR       hallway
# ...                     ...                     ...           ...
# 6294316 2022-03-15 13:22:03  U2dZSjjycMm5bRNvHcLrAr       kitchen
# 6294317 2022-03-15 13:22:08  9YauALfsfPs11tkX1Rb9jq       kitchen
# 6294318 2022-03-15 13:22:08  JQwQLzfRYX5KmetFSg69kK      bathroom
# 6294319 2022-03-15 13:22:10  VmrLbcBzyzacPx8WBnnttf       bedroom
# 6294320 2022-03-15 13:22:12  PFWXtc1ZAL6okGuhVPrabe       hallway
#
# [6273111 rows x 3 columns]

# %% [markdown]
# Now, let's say we decide to merge the study with the lounge location, all we need to run the entire process again and update the mapping dictionary.

# %%
activity = dcarte.load('Activity','raw',since='2022-02-01',until='2022-02-20',reload=False)
mask = ~activity.location_name.isin(['cellar','conservatory'])
activity = activity[mask]
mapping = {
    'bedroom1':'bedroom', 
    'bathroom1':'bathroom', 
    'hallway':'hallway', 
    'lounge':'lounge', 
    'kitchen':'kitchen',
    'living room':'lounge', 
    'corridor1':'hallway', 
    'dining room':'lounge', 
    'WC1':'bathroom', 
    'study':'lounge',
    'office':'lounge'}
activity.location_name = activity.location_name.map(mapping)
activity.location_name.unique()
# Out:
# Finished Loading Activity in:                  2.5 seconds
# array(['bedroom', 'kitchen', 'bathroom', 'lounge', 'hallway'],
#       dtype=object)

# %% [markdown]
# In the end, we now have a single dataset in which the majority of households are similar and there are very few homes with missing locations.

# %%
df = pd.crosstab(activity.location_name,activity.patient_id)
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt 
fig, ax = plt.subplots(figsize=(10,3))
sns.heatmap(df,  norm=LogNorm(),ax=ax)
ax.tick_params(left=False, bottom=False)
ax.set_xticklabels([]);

# %% [markdown]
# Converting this dataset to a wide one-hot encoding format where time and patient ids are the indexes and the different locations are the columns requires calling a pandas function called `pd.get_dummies`.

# %%
activity = activity.set_index(['patient_id','start_date']).location_name
activity = pd.get_dummies(activity)
activity
# Out:
#                                             bathroom  bedroom  hallway  \
# patient_id             start_date
# Dr1tnvKDk2bHG8YS21nwiR 2020-12-09 14:53:17         0        1        0
#                        2020-12-09 14:53:18         0        0        0
#                        2020-12-09 14:53:18         1        0        0
#                        2020-12-09 14:53:19         0        0        0
#                        2020-12-09 14:53:36         0        0        1
# ...                                              ...      ...      ...
# U2dZSjjycMm5bRNvHcLrAr 2022-03-15 13:22:03         0        0        0
# 9YauALfsfPs11tkX1Rb9jq 2022-03-15 13:22:08         0        0        0
# JQwQLzfRYX5KmetFSg69kK 2022-03-15 13:22:08         1        0        0
# VmrLbcBzyzacPx8WBnnttf 2022-03-15 13:22:10         0        1        0
# PFWXtc1ZAL6okGuhVPrabe 2022-03-15 13:22:12         0        0        1
#
#                                             kitchen  lounge
# patient_id             start_date
# Dr1tnvKDk2bHG8YS21nwiR 2020-12-09 14:53:17        0       0
#                        2020-12-09 14:53:18        1       0
#                        2020-12-09 14:53:18        0       0
#                        2020-12-09 14:53:19        0       1
#                        2020-12-09 14:53:36        0       0
# ...                                             ...     ...
# U2dZSjjycMm5bRNvHcLrAr 2022-03-15 13:22:03        1       0
# 9YauALfsfPs11tkX1Rb9jq 2022-03-15 13:22:08        1       0
# JQwQLzfRYX5KmetFSg69kK 2022-03-15 13:22:08        0       0
# VmrLbcBzyzacPx8WBnnttf 2022-03-15 13:22:10        0       0
# PFWXtc1ZAL6okGuhVPrabe 2022-03-15 13:22:12        0       0
#
# [6273111 rows x 5 columns]

# %% [markdown]
# It would be helpful to formalise this process so that it does not require us to run it each time. Formalising derived datasets is another aspect of dcarte that simplifies the collaborations on different parts of data processing. Dcarte comes armed with three samples derived datasets that can be available using a simple command. Running any of the three functions listed below will add a single domain to your dcarte library. These functions will automatically download needed datasets and create the different local datasets described internally.

# %%
from dcarte.derived import (create_base_datasets,
                            create_weekly_profile)
create_base_datasets()
# Out:
# Finished Loading door in:                      0.5 seconds
# Finished Loading doors in:                     0.4 seconds
# Finished Loading environmental in:             0.7 seconds
# Finished Loading device_types in:              0.0 seconds
# Finished Loading appliances in:                0.1 seconds
# Finished Loading doors in:                     0.3 seconds
# Finished Loading activity in:                  2.9 seconds
# Finished Loading device_types in:              0.1 seconds
# Finished Loading sleep_mat in:                 4.0 seconds
# Finished Loading sleep in:                     3.4 seconds
# Finished Loading activity in:                  2.6 seconds
# Finished Loading entryway in:                  0.1 seconds
# Finished Loading bed_occupancy in:             0.1 seconds
# Finished Loading vital_signs in:               0.1 seconds
# Finished Loading blood_pressure in:            0.0 seconds
# Finished Loading device_types in:              0.0 seconds
# Finished Loading motion in:                    1.0 seconds

# %%
create_weekly_profile()
# Out:
# Finished Loading motion in:                    2.7 seconds
# Finished Loading activity_dailies in:          0.1 seconds
# Finished Loading sleep in:                     3.4 seconds
# Finished Loading sleep_dailies in:             0.1 seconds
# Finished Loading physiology in:                0.1 seconds
# Finished Loading physiology_dailies in:        0.1 seconds
# Finished Loading Habitat in:                   0.5 seconds
# Finished Loading Habitat in:                   0.7 seconds

# %% [markdown]
# When you run dcarte.domains() for the final time, you will notice that you now have a greater number of domains under your control than before. In the following section, we will go over one of these recipes in detail and show you how to create an expansion of it on your own using the material you have gained so far in this tutorial.

# %%
dcarte.domains()
# Out:
#                   RAW           BASE       LEGACY         SLEEP_STUDY  \
# 0            Activity  Bed_Occupancy  Device_Type        Acute_Events
# 1          Appliances          Doors        Doors             Diurnal
# 2         Behavioural       Entryway     Entryway      Indoor_Weather
# 3      Blood_Pressure        Habitat        Flags         Local_Sleep
# 4                Door        Kitchen        Light           Nocturnal
# 5           Encounter         Motion       Motion     Outdoor_Weather
# 6       Environmental     Motion_New  Observation       Sleep_Dailies
# 7               Issue     Physiology   Physiology  Study_Demographics
# 8   Observation_Notes          Sleep  Temperature     Withings_Nights
# 9           Procedure    Transitions    Wellbeing       Withings_Tidy
# 10        Sleep_Event
# 11          Sleep_Mat
# 12        Vital_Signs
#
#                 PROFILE        LOOKUP     BED_HABITS
# 0      Activity_Dailies  Device_Types  Bed_Occupancy
# 1     Activity_Weeklies         Homes
# 2                 Light      Patients
# 3    Physiology_Dailies
# 4   Physiology_Weeklies
# 5         Sleep_Dailies
# 6        Sleep_Weeklies
# 7           Temperature
# 8
# 9
# 10
# 11
# 12

# %%
df = dcarte.load('Activity_Dailies','profile')
df
# Out:
# Finished Loading Activity_Dailies in:          0.1 seconds
# location_name                               Bathroom  Bed_in  Bed_out  \
# patient_id             start_date
# 2GN1PHeHwRzNYQ7q4Nvg7g 2021-05-14 12:00:00      22.0     NaN      NaN
#                        2021-05-15 12:00:00      15.0     NaN      NaN
#                        2021-05-16 12:00:00      31.0     NaN      NaN
#                        2021-05-17 12:00:00      20.0     NaN      NaN
#                        2021-05-18 12:00:00      15.0     NaN      NaN
# ...                                              ...     ...      ...
# YYGGmsEaf2gP4JNN9kMprV 2022-03-19 12:00:00       NaN     8.0      8.0
#                        2022-03-20 12:00:00       NaN    12.0     12.0
#                        2022-03-21 12:00:00       NaN     7.0      7.0
#                        2022-03-22 12:00:00       NaN     3.0      3.0
#                        2022-03-23 12:00:00       NaN     8.0      7.0
#
# location_name                               Bedroom  Hallway  Kitchen  Lounge  \
# patient_id             start_date
# 2GN1PHeHwRzNYQ7q4Nvg7g 2021-05-14 12:00:00    170.0     44.0     94.0    46.0
#                        2021-05-15 12:00:00     59.0     37.0    134.0    54.0
#                        2021-05-16 12:00:00    225.0     43.0     94.0    38.0
#                        2021-05-17 12:00:00    153.0     40.0    112.0    38.0
#                        2021-05-18 12:00:00    207.0     35.0     69.0    47.0
# ...                                             ...      ...      ...     ...
# YYGGmsEaf2gP4JNN9kMprV 2022-03-19 12:00:00      NaN      NaN      NaN     NaN
#                        2022-03-20 12:00:00      NaN      NaN      NaN     NaN
#                        2022-03-21 12:00:00      NaN      NaN      NaN     NaN
#                        2022-03-22 12:00:00      NaN      NaN      NaN     NaN
#                        2022-03-23 12:00:00      NaN      NaN      NaN     NaN
#
# location_name                               Total
# patient_id             start_date
# 2GN1PHeHwRzNYQ7q4Nvg7g 2021-05-14 12:00:00  376.0
#                        2021-05-15 12:00:00  299.0
#                        2021-05-16 12:00:00  431.0
#                        2021-05-17 12:00:00  363.0
#                        2021-05-18 12:00:00  373.0
# ...                                           ...
# YYGGmsEaf2gP4JNN9kMprV 2022-03-19 12:00:00   16.0
#                        2022-03-20 12:00:00   24.0
#                        2022-03-21 12:00:00   14.0
#                        2022-03-22 12:00:00    6.0
#                        2022-03-23 12:00:00   15.0
#
# [26701 rows x 8 columns]
